# %%
# #coding=utf-8
# from multiprocessing import Pool
# import scipy
# from scipy import misc
# import os
# import time
# import glob
# from scipy import ndimage
# start = time.time()
# def get_image_paths(folder):# grab the list of files
#     #return (os.path.join(folder, f))
#     #  for f in os.listdir(folder)
#     #        if 'jpg' in f
#     return glob.glob(os.path.join(folder, '*jpg'))
# def create_read_img(filename):
#     im=misc.imread(filename)   #reading images
#     img_rote=ndimage.rotate(im,90) #rotate 90 degree
    
# img_path='/Users/macbookpro/desktop/imageForTrainning/'
# imgs=get_image_paths(img_path)

# %%
import cv2
import os
import glob

img_dir = "/Users/macbookpro/desktop/imageForTrainning"
data_path = os.path.join(img_dir, '*g')
files = glob.glob(data_path)

data = []
for f1 in files:
    img = cv2.imread(f1)
    data.append (img)
    cv2.imshow("Image", img)
# Out:
# [[[ 81 243  77]
#   [ 76 238  72]
#   [ 71 233  67]
#   ...
#   [ 77 229  70]
#   [ 71 223  64]
#   [ 64 216  57]]
#
#  [[ 81 243  77]
#   [ 76 238  72]
#   [ 71 233  67]
#   ...
#   [ 78 230  71]
#   [ 74 226  67]
#   [ 70 222  63]]
#
#  [[ 79 241  75]
#   [ 75 237  71]
#   [ 70 232  66]
#   ...
#   [ 76 228  69]
#   [ 75 227  68]
#   [ 73 225  66]]
#
#  ...
#
#  [[252 248 247]
#   [252 248 247]
#   [252 248 247]
#   ...
#   [227 148 215]
#   [216 137 204]
#   [206 126 193]]
#
#  [[254 250 249]
#   [254 250 249]
#   [254 250 249]
#   ...
#   [206 125 194]
#   [208 127 196]
#   [211 128 197]]
#
#  [[255 251 250]
#   [255 251 250]
#   [255 251 250]
#   ...
#   [197 115 187]
#   [211 127 199]
#   [221 137 209]]]
# [[[255 248 248]
#   [255 247 247]
#   [255 247 247]
#   ...
#   [252 247 246]
#   [252 247 246]
#   [251 246 245]]
#
#  [[255 247 247]
#   [255 247 247]
#   [255 246 246]
#   ...
#   [252 247 246]
#   [251 246 245]
#   [251 246 245]]
#
#  [[255 245 245]
#   [255 245 245]
# ...
